# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings("ignore")

spambase_df = pd.read_csv("spambase_encoded.csv")
mushroom_df = pd.read_csv("mushroom_encoded.csv")
segment_df  = pd.read_csv("segment_encoded.csv")

datasets = {
    "Spambase": spambase_df,
    "Mushroom": mushroom_df,
    "Segment":  segment_df
}

N_REPEATS = 10
N_TREES   = 100
DEPTHS    = [1, 2, 4, 8, 12, 16, 20, 32, None]
FEATURES  = [1, 2, 4, 10, 14, "sqrt", "log2", None]

records = []

# Experiment 1 
for name, df in datasets.items():
    X = df.drop(columns=["class"])
    y = df["class"]

    for d in DEPTHS:
        train_scores = []
        oob_scores = []
        for seed in range(N_REPEATS):
            rf = RandomForestClassifier(
                n_estimators   = N_TREES,
                max_depth      = d,
                max_features   = "sqrt",
                bootstrap      = True,
                oob_score      = True,
                n_jobs         = -1,
                random_state   = seed
            )
            rf.fit(X, y)
            train_scores.append(rf.score(X, y))
            oob_scores.append(rf.oob_score_)

        records.append({
            "Dataset": name,
            "Exp": "Depth",
            "max_depth": d,
            "max_features": "sqrt",
            "Train_mean": np.mean(train_scores),
            "Train_std":  np.std(train_scores),
            "OOB_mean": np.mean(oob_scores),
            "OOB_std":  np.std(oob_scores)
        })

# Get best depth per dataset
df_results = pd.DataFrame(records)
best_depths = df_results[df_results["Exp"] == "Depth"].groupby("Dataset")["OOB_mean"].idxmax()

best_depth_map = {}
for i in best_depths:
    dataset_name = df_results.loc[i, "Dataset"]
    val = df_results.loc[i, "max_depth"]
    if pd.isna(val):
        best_depth_map[dataset_name] = None
    elif isinstance(val, float):
        best_depth_map[dataset_name] = int(val)
    else:
        best_depth_map[dataset_name] = val

# %%
df_results
#df_results.to_csv("df_results.csv", index=False)
# Out:
#      Dataset    Exp  max_depth max_features  Train_mean     Train_std  \
# 0   Spambase  Depth        1.0         sqrt    0.840448  7.924836e-03
# 1   Spambase  Depth        2.0         sqrt    0.893806  4.686978e-03
# 2   Spambase  Depth        4.0         sqrt    0.923734  1.865744e-03
# 3   Spambase  Depth        8.0         sqrt    0.954771  6.257848e-04
# 4   Spambase  Depth       12.0         sqrt    0.976831  7.541557e-04
# 5   Spambase  Depth       16.0         sqrt    0.989807  6.552842e-04
# 6   Spambase  Depth       20.0         sqrt    0.993740  3.477505e-04
# 7   Spambase  Depth       32.0         sqrt    0.999044  1.064764e-04
# 8   Spambase  Depth        NaN         sqrt    0.999304  8.693762e-05
# 9   Mushroom  Depth        1.0         sqrt    0.875037  1.802774e-02
# 10  Mushroom  Depth        2.0         sqrt    0.916864  6.087323e-03
# 11  Mushroom  Depth        4.0         sqrt    0.990251  2.954210e-04
# 12  Mushroom  Depth        8.0         sqrt    1.000000  0.000000e+00
# 13  Mushroom  Depth       12.0         sqrt    1.000000  0.000000e+00
# 14  Mushroom  Depth       16.0         sqrt    1.000000  0.000000e+00
# 15  Mushroom  Depth       20.0         sqrt    1.000000  0.000000e+00
# 16  Mushroom  Depth       32.0         sqrt    1.000000  0.000000e+00
# 17  Mushroom  Depth        NaN         sqrt    1.000000  0.000000e+00
# 18   Segment  Depth        1.0         sqrt    0.675714  5.310418e-02
# 19   Segment  Depth        2.0         sqrt    0.799567  5.790616e-02
# 20   Segment  Depth        4.0         sqrt    0.897403  1.476311e-02
# 21   Segment  Depth        8.0         sqrt    0.975195  1.561445e-03
# 22   Segment  Depth       12.0         sqrt    0.998485  5.212812e-04
# 23   Segment  Depth       16.0         sqrt    0.999567  1.110223e-16
# 24   Segment  Depth       20.0         sqrt    0.999567  1.110223e-16
# 25   Segment  Depth       32.0         sqrt    0.999567  1.110223e-16
# 26   Segment  Depth        NaN         sqrt    0.999567  1.110223e-16
#
#     OOB_mean   OOB_std
# 0   0.835188  0.006977
# 1   0.887959  0.004889
# 2   0.917518  0.002263
# 3   0.937122  0.001329
# 4   0.945686  0.001433
# 5   0.950228  0.001994
# 6   0.952423  0.000810
# 7   0.954771  0.001334
# 8   0.954510  0.001385
# 9   0.873769  0.013884
# 10  0.922009  0.003816
# 11  0.989463  0.000394
# 12  0.999988  0.000037
# 13  1.000000  0.000000
# 14  1.000000  0.000000
# 15  1.000000  0.000000
# 16  1.000000  0.000000
# 17  1.000000  0.000000
# 18  0.574242  0.036152
# 19  0.747706  0.042766
# 20  0.880000  0.012452
# 21  0.959091  0.002096
# 22  0.972511  0.001623
# 23  0.973983  0.001467
# 24  0.973680  0.001407
# 25  0.973723  0.001410
# 26  0.973723  0.001410

# %%
# Experiment 2 
records2 = []

for name, df in datasets.items():
    X = df.drop(columns=["class"])
    y = df["class"]
    best_d = best_depth_map[name]

    for f in FEATURES:
        oob_scores = []
        train_scores = []
        for seed in range(N_REPEATS):
            rf = RandomForestClassifier(
                n_estimators   = N_TREES,
                max_depth      = best_d,
                max_features   = f,
                bootstrap      = True,
                oob_score      = True,
                n_jobs         = -1,
                random_state   = seed
            )
            rf.fit(X, y)
            train_scores.append(rf.score(X, y))
            oob_scores.append(rf.oob_score_)

        records2.append({
            "Dataset": name,
            "Exp": "Features",
            "max_depth": best_d,
            "max_features": f,
            "Train_mean": np.mean(train_scores),
            "Train_std":  np.std(train_scores),
            "OOB_mean": np.mean(oob_scores),
            "OOB_std":  np.std(oob_scores)
        })

# %%
df_results2 = pd.DataFrame(records2)
df_results2
#df_results2.to_csv("df_results2.csv", index=False)
# Out:
#      Dataset       Exp  max_depth max_features  Train_mean     Train_std  \
# 0   Spambase  Features         32            1    0.993023  3.820560e-04
# 1   Spambase  Features         32            2    0.996175  3.662747e-04
# 2   Spambase  Features         32            4    0.998326  3.081384e-04
# 3   Spambase  Features         32           10    0.999065  2.184281e-04
# 4   Spambase  Features         32           14    0.999152  1.521408e-04
# 5   Spambase  Features         32         sqrt    0.999044  1.064764e-04
# 6   Spambase  Features         32         log2    0.998826  2.216483e-04
# 7   Spambase  Features         32         None    0.999022  2.429980e-04
# 8   Mushroom  Features         12            1    1.000000  0.000000e+00
# 9   Mushroom  Features         12            2    1.000000  0.000000e+00
# 10  Mushroom  Features         12            4    1.000000  0.000000e+00
# 11  Mushroom  Features         12           10    1.000000  0.000000e+00
# 12  Mushroom  Features         12           14    1.000000  0.000000e+00
# 13  Mushroom  Features         12         sqrt    1.000000  0.000000e+00
# 14  Mushroom  Features         12         log2    1.000000  0.000000e+00
# 15  Mushroom  Features         12         None    1.000000  0.000000e+00
# 16   Segment  Features         16            1    0.999567  1.110223e-16
# 17   Segment  Features         16            2    0.999567  1.110223e-16
# 18   Segment  Features         16            4    0.999567  1.110223e-16
# 19   Segment  Features         16           10    0.999567  1.110223e-16
# 20   Segment  Features         16           14    0.999567  1.110223e-16
# 21   Segment  Features         16         sqrt    0.999567  1.110223e-16
# 22   Segment  Features         16         log2    0.999567  1.110223e-16
# 23   Segment  Features         16         None    0.999481  1.731602e-04
#
#     OOB_mean   OOB_std
# 0   0.952793  0.001032
# 1   0.954945  0.001322
# 2   0.955162  0.000542
# 3   0.953967  0.001174
# 4   0.951837  0.001163
# 5   0.954771  0.001334
# 6   0.955770  0.001519
# 7   0.948316  0.000884
# 8   1.000000  0.000000
# 9   1.000000  0.000000
# 10  1.000000  0.000000
# 11  1.000000  0.000000
# 12  1.000000  0.000000
# 13  1.000000  0.000000
# 14  1.000000  0.000000
# 15  1.000000  0.000000
# 16  0.964848  0.001855
# 17  0.970606  0.000917
# 18  0.973983  0.001467
# 19  0.975152  0.001358
# 20  0.975628  0.001356
# 21  0.973983  0.001467
# 22  0.973983  0.001467
# 23  0.973420  0.001258

# %%
#  Experiment 3 
records3 = []


for name, df in datasets.items():
    X = df.drop(columns=["class"])
    y = df["class"]

    for d in [1, 2, 4, 8, 16 ,32, None]:
        for f in [1, 2, 4, 14, "sqrt", None]:
            oob_scores = []
            train_scores = []
            for seed in range(N_REPEATS):
                rf = RandomForestClassifier(
                    n_estimators   = N_TREES,
                    max_depth      = d,
                    max_features   = f,
                    bootstrap      = True,
                    oob_score      = True,
                    n_jobs         = -1,
                    random_state   = seed
                )
                rf.fit(X, y)
                train_scores.append(rf.score(X, y))
                oob_scores.append(rf.oob_score_)

            records3.append({
                "Dataset": name,
                "Exp": "Grid",
                "max_depth": d,
                "max_features": f,
                "Train_mean": np.mean(train_scores),
                "Train_std":  np.std(train_scores),
                "OOB_mean": np.mean(oob_scores),
                "OOB_std":  np.std(oob_scores)
            })

# %%
df_results3 = pd.DataFrame(records3)
df_results3
# Out:
#       Dataset   Exp  max_depth max_features  Train_mean     Train_std  \
# 0    Spambase  Grid        1.0            1    0.682026  1.326796e-02
# 1    Spambase  Grid        1.0            2    0.761813  1.646988e-02
# 2    Spambase  Grid        1.0            4    0.814779  1.130139e-02
# 3    Spambase  Grid        1.0           14    0.857727  6.267805e-03
# 4    Spambase  Grid        1.0         sqrt    0.840448  7.924836e-03
# ..        ...   ...        ...          ...         ...           ...
# 121   Segment  Grid        NaN            2    0.999567  1.110223e-16
# 122   Segment  Grid        NaN            4    0.999567  1.110223e-16
# 123   Segment  Grid        NaN           14    0.999567  1.110223e-16
# 124   Segment  Grid        NaN         sqrt    0.999567  1.110223e-16
# 125   Segment  Grid        NaN         None    0.999567  1.110223e-16
#
#      OOB_mean   OOB_std
# 0    0.687090  0.013771
# 1    0.757509  0.015757
# 2    0.808911  0.011350
# 3    0.852184  0.007206
# 4    0.835188  0.006977
# ..        ...       ...
# 121  0.970476  0.001092
# 122  0.973723  0.001410
# 123  0.975455  0.001043
# 124  0.973723  0.001410
# 125  0.973723  0.001096
#
# [126 rows x 8 columns]

# %%
df_results3.to_csv("df_results3.csv", index=False)
